# %%
import pandas
df = pandas.read_csv("new.csv")

# %%
df
# Out:
#      Rank                                         Major Early Career Pay  \
# 0       1                         Petroleum Engineering           $97500
# 1       2  Operations Research & Industrial Engineering           $98300
# 2       3                            Interaction Design           $74700
# 3       4              Applied Economics and Management           $76500
# 4       5                              Building Science           $69000
# ..    ...                                           ...              ...
# 818   795                                Equine Studies           $40300
# 819   796                         Addictions Counseling           $45900
# 820   797                      Nonprofit Administration           $42800
# 821   798                     Early Childhood Education           $41700
# 822   799                                 Metalsmithing           $44700
#
#     Mid Career Pay % High Meaning
# 0          $212500            61%
# ...
