# %%
import pandas
df = pandas.read_csv("salaries_by_college_major.csv")
print(df)
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.columns[0]
# Out:
# 'Undergraduate Major'

# %%
df["Mid-Career 10th Percentile Salary"]
# Out:
# 0     42200.0
# 1     64300.0
# 2     36300.0
# 3     33800.0
# 4     50600.0
# 5     28800.0
# 6     36900.0
# 7     38800.0
# 8     71900.0
# 9     45300.0
# 10    63400.0
# 11    37500.0
# 12    66100.0
# 13    56000.0
# 14    56300.0
# 15    32200.0
# 16    36700.0
# 17    50600.0
# 18    29300.0
# 19    69300.0
# 20    33400.0
# 21    33900.0
# 22    47200.0
# 23    41000.0
# 24    40000.0
# 25    45000.0
# 26    36000.0
# 27    34600.0
# 28    37000.0
# 29    35500.0
# 30    57100.0
# 31    44500.0
# 32    35700.0
# 33    38200.0
# 34    38400.0
# 35    45300.0
# 36    42100.0
# 37    45200.0
# 38    63700.0
# 39    26700.0
# 40    47600.0
# 41    33900.0
# 42    35500.0
# 43    66400.0
# 44    56000.0
# 45    41200.0
# 46    31600.0
# 47    29700.0
# 48    30700.0
# 49    31000.0
# 50        NaN
# Name: Mid-Career 10th Percentile Salary, dtype: float64

# %%
df.loc[df['Mid-Career 10th Percentile Salary'] > 50000]
# Out:
#        Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 1    Aerospace Engineering                 57700.0                  101000.0
# 4             Architecture                 41600.0                   76800.0
# 8     Chemical Engineering                 63200.0                  107000.0
# 10       Civil Engineering                 53900.0                   90500.0
# 12    Computer Engineering                 61400.0                  105000.0
# 13        Computer Science                 55900.0                   95500.0
# 14            Construction                 53700.0                   88900.0
# 17               Economics                 50100.0                   98600.0
# 19  Electrical Engineering                 60900.0                  103000.0
# 30  Industrial Engineering                 57700.0                   94700.0
# 38  Mechanical Engineering                 57900.0                   93600.0
# ...

# %%
df.iloc[10:20,0:2]
# Out:
#        Undergraduate Major  Starting Median Salary
# 10       Civil Engineering                 53900.0
# 11          Communications                 38100.0
# 12    Computer Engineering                 61400.0
# 13        Computer Science                 55900.0
# 14            Construction                 53700.0
# 15        Criminal Justice                 35000.0
# 16                   Drama                 35900.0
# 17               Economics                 50100.0
# 18               Education                 34900.0
# 19  Electrical Engineering                 60900.0

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
clean_df = df.dropna()
#print(clean_df)
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
#individual cells
#using loc and iloc
#clean_df.iloc[0:5,0:5]
clean_df.iloc[0:1,0:1]
# Out:
#   Undergraduate Major
# 0          Accounting

# %%
#individual cells
#using loc and iloc
clean_df["Undergraduate Major"].loc[0]
# Out:
# 'Accounting'

# %%
df["Starting Median Salary"].max()
# Out:
# 74300.0

# %%
df["Starting Median Salary"].idxmax()
# Out:
# 43

# %%
df["Starting Median Salary"].idxmin()
# Out:
# 49

# %%
clean_df["Starting Median Salary"].loc[43]
# Out:
# 74300.0

# %%
clean_df["Starting Median Salary"].loc[49]
# Out:
# 34000.0

# %%
clean_df.loc[0]
# Out:
# Undergraduate Major                  Accounting
# Starting Median Salary                  46000.0
# Mid-Career Median Salary                77100.0
# Mid-Career 10th Percentile Salary       42200.0
# Mid-Career 90th Percentile Salary      152000.0
# Group                                  Business
# Name: 0, dtype: object

# %%
clean_df["Mid-Career Median Salary"].max()
# Out:
# 107000.0

# %%
clean_df["Mid-Career Median Salary"].min()
# Out:
# 52000.0

# %%
clean_df["Starting Median Salary"].min()
# Out:
# 34000.0

# %%
clean_df["Mid-Career Median Salary"].idxmax()
# Out:
# 8

# %%
clean_df["Mid-Career Median Salary"].idxmin()
# Out:
# 18

# %%
clean_df["Starting Median Salary"].idxmin()
# Out:
# 49

# %%
print("Max Mid-Career Median Salary")
clean_df["Undergraduate Major"].loc[8]
# Out:
# Max Mid-Career Median Salary
# 'Chemical Engineering'

# %%
print("Min Mid-Career Median Salary")
clean_df["Undergraduate Major"].loc[18]
# Out:
# Min Mid-Career Median Salary
# 'Education'

# %%
print("Min Starting Median Salary")
clean_df["Undergraduate Major"].loc[49]
# Out:
# Min Starting Median Salary
# 'Spanish'

# %%
clean_df.loc[df["Mid-Career Median Salary"].idxmin()]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %%
clean_df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
diff = clean_df["Mid-Career 90th Percentile Salary"] - clean_df["Mid-Career 10th Percentile Salary"]
print(diff)
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
#clean_df.insert(1,"Difference",diff)

# %%
clean_df
# Out:
#                      Undergraduate Major  Difference  Starting Median Salary  \
# 0                             Accounting    109800.0                 46000.0
# 1                  Aerospace Engineering     96700.0                 57700.0
# 2                            Agriculture    113700.0                 42600.0
# 3                           Anthropology    104200.0                 36800.0
# 4                           Architecture     85400.0                 41600.0
# 5                            Art History     96200.0                 35800.0
# 6                                Biology     98100.0                 38800.0
# 7                    Business Management    108200.0                 43000.0
# 8                   Chemical Engineering    122100.0                 63200.0
# 9                              Chemistry    102700.0                 42600.0
# 10                     Civil Engineering     84600.0                 53900.0
# ...

# %%
clean_df.sort_values(by=["Difference"],ascending=True).head(5)
# Out:
#            Undergraduate Major  Difference  Starting Median Salary  \
# 40                     Nursing     50700.0                 54200.0
# 43         Physician Assistant     57600.0                 74300.0
# 41                   Nutrition     65300.0                 39900.0
# 49                     Spanish     65400.0                 34000.0
# 27  Health Care Administration     66400.0                 38800.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 40                   67000.0                            47600.0
# 43                   91700.0                            66400.0
# 41                   55300.0                            33900.0
# 49                   53100.0                            31000.0
# 27                   60600.0                            34600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 40                            98300.0  Business
# 43                           124000.0      STEM
# ...

# %%
clean_df.sort_values(by=["Difference"],ascending=False).head(5)
# Out:
#    Undergraduate Major  Difference  Starting Median Salary  \
# 17           Economics    159400.0                 50100.0
# 22             Finance    147800.0                 47900.0
# 37                Math    137800.0                 45400.0
# 36           Marketing    132900.0                 40800.0
# 42          Philosophy    132500.0                 39900.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
# 22                   88300.0                            47200.0
# 37                   92400.0                            45200.0
# 36                   79600.0                            42100.0
# 42                   81200.0                            35500.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business
# 22                           195000.0  Business
# 37                           183000.0      STEM
# ...

# %%
clean_df.sort_values(by="Mid-Career 90th Percentile Salary",ascending=False).head(5)
# Out:
#      Undergraduate Major  Difference  Starting Median Salary  \
# 17             Economics    159400.0                 50100.0
# 22               Finance    147800.0                 47900.0
# 8   Chemical Engineering    122100.0                 63200.0
# 37                  Math    137800.0                 45400.0
# 44               Physics    122000.0                 50300.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
# 22                   88300.0                            47200.0
# 8                   107000.0                            71900.0
# 37                   92400.0                            45200.0
# 44                   97300.0                            56000.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business
# 22                           195000.0  Business
# 8                            194000.0      STEM
# ...

# %%
a = clean_df["Difference"].max()

# %%
clean_df.loc[clean_df["Difference"]==a]
# Out:
#    Undergraduate Major  Difference  Starting Median Salary  \
# 17           Economics    159400.0                 50100.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 17                   98600.0                            50600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 17                           210000.0  Business

# %%
highest_spread = clean_df["Mid-Career Median Salary"].sort_values(ascending=False).head(5)
print(highest_spread)
# Out:
# 8     107000.0
# 12    105000.0
# 19    103000.0
# 1     101000.0
# 17     98600.0
# Name: Mid-Career Median Salary, dtype: float64

# %%
print(type(highest_spread))
# Out:
# <class 'pandas.core.series.Series'>

# %%
clean_df.loc[highest_spread.index]
# Out:
#        Undergraduate Major  Difference  Starting Median Salary  \
# 8     Chemical Engineering    122100.0                 63200.0
# 12    Computer Engineering     95900.0                 61400.0
# 19  Electrical Engineering     98700.0                 60900.0
# 1    Aerospace Engineering     96700.0                 57700.0
# 17               Economics    159400.0                 50100.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 8                   107000.0                            71900.0
# 12                  105000.0                            66100.0
# 19                  103000.0                            69300.0
# 1                   101000.0                            64300.0
# 17                   98600.0                            50600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 8                            194000.0      STEM
# 12                           162000.0      STEM
# 19                           168000.0      STEM
# ...

# %%
highest_spread.index
# Out:
# Index([8, 12, 19, 1, 17], dtype='int64')

# %%
clean_df.groupby(by="Group").count()
# Out:
#           Undergraduate Major  Difference  Starting Median Salary  \
# Group
# Business                   12          12                      12
# HASS                       22          22                      22
# STEM                       16          16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                                 12
# HASS                                     22
# STEM                                     16

# %%
new_df = clean_df.drop(["Undergraduate Major","Group"],axis=1)

# %%
new_df.head(5)
# Out:
#    Difference  Starting Median Salary  Mid-Career Median Salary  \
# 0  109,800.00               46,000.00                 77,100.00
# 1   96,700.00               57,700.00                101,000.00
# 2  113,700.00               42,600.00                 71,900.00
# 3  104,200.00               36,800.00                 61,500.00
# 4   85,400.00               41,600.00                 76,800.00
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                          42,200.00                         152,000.00
# 1                          64,300.00                         161,000.00
# 2                          36,300.00                         150,000.00
# 3                          33,800.00                         138,000.00
# 4                          50,600.00                         136,000.00

# %%
clean_df.groupby(by=["Group"])[new_df.columns].mean()
# Out:
#           Difference  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business  103,958.33               44,633.33                 75,083.33
# HASS       95,218.18               37,186.36                 62,968.18
# STEM      101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00

# %%
clean_df.groupby(by=["Group","Undergraduate Major"])[new_df.columns].mean()
# Out:
#                                                Difference  \
# Group    Undergraduate Major
# Business Accounting                            109,800.00
#          Agriculture                           113,700.00
#          Architecture                           85,400.00
#          Business Management                   108,200.00
#          Construction                          114,700.00
#          Economics                             159,400.00
#          Finance                               147,800.00
#          Forestry                               70,000.00
#          Health Care Administration             66,400.00
#          Hospitality & Tourism                  88,500.00
#          Marketing                             132,900.00
#          Nursing                                50,700.00
# HASS     Anthropology                          104,200.00
#          Art History                            96,200.00
#          Communications                        105,500.00
# ...

# %%
clean_df.columns
# Out:
# Index(['Undergraduate Major', 'Difference', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
pandas.options.display.float_format = '{:,.2f}'.format

# %%
clean_df.shape
# Out:
# (50, 7)

# %%
df.loc[df['Mid-Career 10th Percentile Salary'] > 50000]
# Out:
#        Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 1    Aerospace Engineering                 57700.0                  101000.0
# 4             Architecture                 41600.0                   76800.0
# 8     Chemical Engineering                 63200.0                  107000.0
# 10       Civil Engineering                 53900.0                   90500.0
# 12    Computer Engineering                 61400.0                  105000.0
# 13        Computer Science                 55900.0                   95500.0
# 14            Construction                 53700.0                   88900.0
# 17               Economics                 50100.0                   98600.0
# 19  Electrical Engineering                 60900.0                  103000.0
# 30  Industrial Engineering                 57700.0                   94700.0
# 38  Mechanical Engineering                 57900.0                   93600.0
# ...

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...
